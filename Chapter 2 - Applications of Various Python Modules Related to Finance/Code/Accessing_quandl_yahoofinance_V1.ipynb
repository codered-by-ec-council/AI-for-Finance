# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><span style="font-family:Comic Sans MS">Accessing Quandl</span></b>
# </div>

# %%
# Install quandl package
# !pip install quandl

# %%
# Import quandl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import quandl
# Get the data for Coca-cola
data = quandl.get("WIKI/KO", start_date="2014-01-01", end_date="2021-03-01", api_key="<<Your API Key>>")
# Plot the prices
data.Close.plot()
plt.show()

# %%
# Import quandl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import quandl
# Get the data for ABN Amro Group from the Euronext Stock Exchange
data = quandl.get("EURONEXT/ABN", start_date="2014-01-01", end_date="2021-03-01", api_key="<<Your API Key Here>>")
# Plot the prices
data.Last.plot()
plt.show()

# %%
# Generate a QQ plot
# %matplotlib inline
import quandl
from scipy import stats
from scipy.stats import probplot
# Get the data for ABN Amro Group from the Euronext Stock Exchange
df = quandl.get("EURONEXT/ABN", start_date="2014-01-01", end_date="2021-03-01", api_key="aXWysdzLEVaSBAyCGKcx")
daily_changes = df.pct_change(periods=1).dropna()
figure = plt.figure(figsize=(8,4))
ax = figure.add_subplot(111)
stats.probplot(daily_changes['Last'], dist='norm', plot=ax)
plt.show();

# %%
# Get the data for Gold Futures, Continuous Contract #6.
data = quandl.get("CHRIS/CME_GC6", start_date="2010-01-01", end_date="2019-12-01", api_key="<<Your API Key Here>>")
# Plot the prices
data.Last.plot()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><span style="font-family:Comic Sans MS">Accessing yfinance</span></b>
# </div>

# %%
# Install yfinance and matplotlib package
# !pip install yfinance
# !pip install matplotlib

# %%
# Import yfinance and matplotlib
import yfinance as yf  
import matplotlib.pyplot as plt
# Get the data for the Apple stock price by specifying the stock ticker, start date, and end date
data = yf.download('AAPL','2010-01-01','2021-03-01')
# Plot the close prices
data["Adj Close"].plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Get the data for the SPY (an ETF on the S&P 500 index) and the stock Apple by specifying the stock ticker, start date, and end date
data = yf.download(['SPY', 'AAPL','FB','AMZN'],'2015-01-01','2021-03-22')
# Plot the adjusted close prices
data["Adj Close"].plot()
plt.show()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
# Get the data for the stock Apple by specifying the stock ticker, start date, and end date
data = yf.download(['BTC-USD', 'EURUSD=X', 'CL=F', 'ARKK', '^TNX','AAPL' ],'2010-01-01','2021-03-25')
data["Adj Close"].tail()
# Out:
# [*********************100%***********************]  6 of 6 completed
#                   AAPL        ARKK       BTC-USD       CL=F  EURUSD=X   ^TNX
# Date
# 2021-03-20         NaN         NaN  58313.644531        NaN       NaN    NaN
# 2021-03-21         NaN         NaN  57523.421875        NaN       NaN    NaN
# 2021-03-22  123.389999  124.720001  54529.144531  61.549999  1.188312  1.684
# 2021-03-23  122.540001  121.699997  54738.945312  57.759998  1.193303  1.638
# 2021-03-24  120.089996  114.779999  52774.265625  61.180000  1.184021  1.614
